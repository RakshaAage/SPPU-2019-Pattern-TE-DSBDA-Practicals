# %%
Perform the following operations using Python on Iris data set.
1. Load the Dataset into pandas data frame.
2. Display information about missing values in the data
3. Display initial statistics.
4. Check the dimensions of the data frame.
5. Display data type of the variable.
6. Apply proper data type conversion
7. Convert categorical variables into quantitative variables using one hot
encoding and label encoder

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#from sklearn.datasets import load_iris
from sklearn.compose import ColumnTransformer

# Load the Iris dataset
iris_df = pd.read_csv("Iris.csv")

# Adding target column
iris_df['target'] = iris_df['Species']

# 2. Display information about missing values in the data
print("Missing Values Information:")
print(iris_df.isnull().sum())

# 3. Display initial statistics
print("\nInitial Statistics:")
print(iris_df.describe())

# 4. Check the dimensions of the data frame
print("\nDimensions of the Data Frame:")
print(iris_df.shape)

# 5. Display data type of the variables
print("\nData Types of Variables:")
print(iris_df.dtypes)

# 6. Apply proper data type conversion
# No conversion needed as the data types are already numeric

# 7. Convert categorical variables into quantitative variables using one hot encoding and label encoder
# Label encode the target variable
label_encoder = LabelEncoder()
iris_df['target_encoded'] = label_encoder.fit_transform(iris_df['target'])

# Apply one-hot encoding to categorical variables (not needed for Iris dataset as there are no categorical variables)

# Display the modified DataFrame
print("\nModified DataFrame:")
print(iris_df.head())
# Out:
# Missing Values Information:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# target           0
# dtype: int64
#
# Initial Statistics:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
# Dimensions of the Data Frame:
# (150, 7)
#
# Data Types of Variables:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# target            object
# dtype: object
#
# Modified DataFrame:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#         target  target_encoded
# 0  Iris-setosa               0
# 1  Iris-setosa               0
# 2  Iris-setosa               0
# 3  Iris-setosa               0
# 4  Iris-setosa               0
